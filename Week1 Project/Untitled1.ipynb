# %%
# Project Week 1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import files
df_1 = pd.read_csv('continents.csv', sep = ';')
df_2 = pd.read_csv('gapminder_total_fertility.csv',  sep = ';')
df_3 = pd.read_excel('gapminder_lifeexpectancy.xlsx', index_col=0)
df_4 = pd.read_excel('gapminder_population.xlsx')

# %%
df_3.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, Abkhazia to South Sudan
# Columns: 217 entries, 1800 to 2016
# dtypes: float64(217)
# memory usage: 442.8+ KB

# %%
df_3.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'South Sudan'],
#       dtype='object', name='Life expectancy', length=260)

# %%
df_3.reset_index(inplace=True)
df_3.head()
# Out:
#          Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# 4  76.50
#
# ...

# %%
df_3.rename(columns={'Life expectancy': 'country'}, inplace=True)
df_3.head()
# Out:
#                  country   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# 4  76.50
#
# ...

# %%
tidy_life = pd.melt(df_3,
                         id_vars='country',
                         var_name='year',
                         value_name='Life expectancy')
tidy_life.head()
# Out:
#                  country  year  Life expectancy
# 0               Abkhazia  1800              NaN
# 1            Afghanistan  1800            28.21
# 2  Akrotiri and Dhekelia  1800              NaN
# 3                Albania  1800            35.40
# 4                Algeria  1800            28.82

# %%
type(tidy_life)
# Out:
# pandas.core.frame.DataFrame

# %%
tidy_life.columns
# Out:
# Index(['country', 'year', 'Life expectancy'], dtype='object')

# %%
df_2.index
# Out:
# RangeIndex(start=0, stop=260, step=1)

# %%
df_2.rename(columns={'Total fertility rate': 'country'}, inplace=True)
df_2.head()
# Out:
#                  country     1800     1801     1802     1803     1804  \
# 0               Abkhazia      NaN      NaN      NaN      NaN      NaN
# 1            Afghanistan      7.0      7.0      7.0      7.0      7.0
# 2  Akrotiri and Dhekelia      NaN      NaN      NaN      NaN      NaN
# 3                Albania  04. Jun  04. Jun  04. Jun  04. Jun  04. Jun
# 4                Algeria   Jun 99   Jun 99   Jun 99   Jun 99   Jun 99
#
#       1805     1806     1807     1808  ...     2007     2008    2009    2010  \
# 0      NaN      NaN      NaN      NaN  ...      NaN      NaN     NaN     NaN
# 1      7.0      7.0      7.0      7.0  ...   Jun 46  06. Feb  Mai 93  Mai 66
# 2      NaN      NaN      NaN      NaN  ...      NaN      NaN     NaN     NaN
# 3  04. Jun  04. Jun  04. Jun  04. Jun  ...  01. Aug   Jan 76  Jan 74  Jan 74
# 4   Jun 99   Jun 99   Jun 99   Jun 99  ...   Feb 66   Feb 73  Feb 78  Feb 82
#
#       2011    2012     2013    2014    2015 Unnamed: 217
# ...

# %%
df_2.rename(columns={'Total fertility rate': 'country'}, inplace=True)
df_2.head()
# Out:
#                  country     1800     1801     1802     1803     1804  \
# 0               Abkhazia      NaN      NaN      NaN      NaN      NaN
# 1            Afghanistan      7.0      7.0      7.0      7.0      7.0
# 2  Akrotiri and Dhekelia      NaN      NaN      NaN      NaN      NaN
# 3                Albania  04. Jun  04. Jun  04. Jun  04. Jun  04. Jun
# 4                Algeria   Jun 99   Jun 99   Jun 99   Jun 99   Jun 99
#
#       1805     1806     1807     1808  ...     2007     2008    2009    2010  \
# 0      NaN      NaN      NaN      NaN  ...      NaN      NaN     NaN     NaN
# 1      7.0      7.0      7.0      7.0  ...   Jun 46  06. Feb  Mai 93  Mai 66
# 2      NaN      NaN      NaN      NaN  ...      NaN      NaN     NaN     NaN
# 3  04. Jun  04. Jun  04. Jun  04. Jun  ...  01. Aug   Jan 76  Jan 74  Jan 74
# 4   Jun 99   Jun 99   Jun 99   Jun 99  ...   Feb 66   Feb 73  Feb 78  Feb 82
#
#       2011    2012     2013    2014    2015 Unnamed: 217
# ...

# %%
tidy_fertility = pd.melt(df_2,
                         id_vars='country',
                         var_name='year',
                         value_name='Total fertility rate')
tidy_fertility.head()
# Out:
#                  country  year Total fertility rate
# 0               Abkhazia  1800                  NaN
# 1            Afghanistan  1800                  7.0
# 2  Akrotiri and Dhekelia  1800                  NaN
# 3                Albania  1800              04. Jun
# 4                Algeria  1800               Jun 99

# %%
tidy_fertility['year'] = tidy_fertility['year'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-3461848e66f4> in <module>
# ----> 1 tidy_fertility['year'] = tidy_fertility['year'].astype('int')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df_1.head()
# Out:
#   continent   country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %%
df_4.head()
# Out:
#         Total population       1800       1810       1820       1830  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania   410445.0   423591.0   438671.0   457234.0
# 4                Algeria  2503218.0  2595056.0  2713079.0  2880355.0
#
#         1840       1850       1860       1870       1880  ...  Unnamed: 82  \
# 0        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1  3625022.0  3810047.0  3973968.0  4169690.0  4419695.0  ...          NaN
# 2        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 3   478227.0   506889.0   552800.0   610036.0   672544.0  ...          NaN
# 4  3082721.0  3299305.0  3536468.0  3811028.0  4143163.0  ...          NaN
#
#    Unnamed: 83  Unnamed: 84  Unnamed: 85  Unnamed: 86  Unnamed: 87  \
# ...

# %%
df_4.rename(columns={'Total population': 'country'}, inplace=True)
tidy_popul = pd.melt(df_4,
                         id_vars='country',
                         var_name='year',
                         value_name='Total population')
tidy_popul.head()
# Out:
#                  country  year  Total population
# 0               Abkhazia  1800               NaN
# 1            Afghanistan  1800         3280000.0
# 2  Akrotiri and Dhekelia  1800               NaN
# 3                Albania  1800          410445.0
# 4                Algeria  1800         2503218.0

# %%
#df_1(Continent) = df_1
#fert(Total Fertility Rate) = tidy_fertility
#lifedf_3(Life expectancy) = tidy_life
#df_4 (gapminder_population)= tidy_popul

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   continent  194 non-null    object
#  1   country    194 non-null    object
# dtypes: object(2)
# memory usage: 3.2+ KB

# %%
tidy_fertility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56420 entries, 0 to 56419
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               56420 non-null  object
#  1   year                  56420 non-null  object
#  2   Total fertility rate  43418 non-null  object
# dtypes: object(3)
# memory usage: 1.3+ MB

# %%
tidy_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56420 entries, 0 to 56419
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          56420 non-null  object
#  1   year             56420 non-null  object
#  2   Life expectancy  43857 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ MB

# %%
tidy_life['year'] = tidy_life['year'].astype('int')

# %%
type(tidy_life)
# Out:
# pandas.core.frame.DataFrame

# %%
tidy_fertility
# Out:
#                      country          year Total fertility rate
# 0                   Abkhazia          1800                  NaN
# 1                Afghanistan          1800                  7.0
# 2      Akrotiri and Dhekelia          1800                  NaN
# 3                    Albania          1800              04. Jun
# 4                    Algeria          1800               Jun 99
# ...                      ...           ...                  ...
# 56415             Yugoslavia  Unnamed: 217                  NaN
# 56416                 Zambia  Unnamed: 217                  NaN
# 56417               Zimbabwe  Unnamed: 217                  NaN
# 56418                  Åland  Unnamed: 217                  NaN
# 56419                  Åland  Unnamed: 217                  NaN
#
# [56420 rows x 3 columns]

# %%
tidy_popul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25025 entries, 0 to 25024
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           25025 non-null  object
#  1   year              25025 non-null  object
#  2   Total population  20176 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 586.6+ KB

# %%
df_99 = pd.merge(df_1, tidy_fertility, how='right', on="country")

# %%
df_98 = pd.merge(tidy_life, tidy_popul, how='right', on="country")

# %%
tidy_popul = tidy_popul['Total population'].astype('object')

# %%
df_99 = pd.merge(df_1, tidy_fertility, how='right', on="country")

# %%
df_99.head()
# Out:
#   continent                country  year Total fertility rate
# 0       NaN               Abkhazia  1800                  NaN
# 1      Asia            Afghanistan  1800                  7.0
# 2       NaN  Akrotiri and Dhekelia  1800                  NaN
# 3    Europe                Albania  1800              04. Jun
# 4    Africa                Algeria  1800               Jun 99

# %%
df_98.head()
# Out:
#     country  year_x  Life expectancy year_y  Total population
# 0  Abkhazia  1800.0              NaN   1800               NaN
# 1  Abkhazia  1801.0              NaN   1800               NaN
# 2  Abkhazia  1802.0              NaN   1800               NaN
# 3  Abkhazia  1803.0              NaN   1800               NaN
# 4  Abkhazia  1804.0              NaN   1800               NaN

# %%
tidy_life.head()
# Out:
#                  country  year  Life expectancy
# 0               Abkhazia  1800              NaN
# 1            Afghanistan  1800            28.21
# 2  Akrotiri and Dhekelia  1800              NaN
# 3                Albania  1800            35.40
# 4                Algeria  1800            28.82

# %%
df_list = [df_1,tidy_fertility, tidy_life,tidy_popul]
df_all = pd.concat(df_list).reset_index(drop=True)
