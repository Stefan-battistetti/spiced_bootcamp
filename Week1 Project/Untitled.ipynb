# %%
# Project Week 1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import files
df_1 = pd.read_csv('continents.csv', sep = ';')
df_2 = pd.read_csv('gapminder_total_fertility.csv', index_col=0)
df_3 = pd.read_excel('gapminder_lifeexpectancy.xlsx', index_col=0)
df_4 = pd.read_excel('gapminder_population.xlsx')

# %%
df_3.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, Abkhazia to South Sudan
# Columns: 217 entries, 1800 to 2016
# dtypes: float64(217)
# memory usage: 442.8+ KB

# %%
df_3.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'South Sudan'],
#       dtype='object', name='Life expectancy', length=260)

# %%
df_3.reset_index(inplace=True)
df_3.head()
# Out:
#          Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# 4  76.50
#
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Columns: 218 entries, Life expectancy to 2016
# dtypes: float64(217), object(1)
# memory usage: 442.9+ KB

# %%
df_3.shape
# Out:
# (260, 218)

# %%
df_3.rename(columns={'Life expectancy': 'country'}, inplace=True)
df_3.head()
# Out:
#                  country   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# 4  76.50
#
# ...

# %%
tidy_life = pd.melt(df_3, id_vars='country', var_name='year', value_name='life_expectancy')
tidy_life.head()
# Out:
#                  country  year  life_expectancy
# 0               Abkhazia  1800              NaN
# 1            Afghanistan  1800            28.21
# 2  Akrotiri and Dhekelia  1800              NaN
# 3                Albania  1800            35.40
# 4                Algeria  1800            28.82

# %%
tidy_life.loc[tidy_life['country']=='Afghanistan']
# Out:
#            country  year  life_expectancy
# 1      Afghanistan  1800            28.21
# 261    Afghanistan  1801            28.20
# 521    Afghanistan  1802            28.19
# 781    Afghanistan  1803            28.18
# 1041   Afghanistan  1804            28.17
# ...            ...   ...              ...
# 55121  Afghanistan  2012            54.40
# 55381  Afghanistan  2013            54.80
# 55641  Afghanistan  2014            54.90
# 55901  Afghanistan  2015            53.80
# 56161  Afghanistan  2016            52.72
#
# [217 rows x 3 columns]

# %%
#acessing one value
tidy_life.loc['Afghanistan']
# Out:
#              year  life_expectancy
# country
# Afghanistan  1800            28.21
# Afghanistan  1801            28.20
# Afghanistan  1802            28.19
# Afghanistan  1803            28.18
# Afghanistan  1804            28.17
# ...           ...              ...
# Afghanistan  2012            54.40
# Afghanistan  2013            54.80
# Afghanistan  2014            54.90
# Afghanistan  2015            53.80
# Afghanistan  2016            52.72
#
# [217 rows x 2 columns]

# %%
# Out:
#   File "<ipython-input-176-8143fcf4378d>", line 1
#     tidy_life.loc[(tidy_life)['country']=='Albania') & (tidy_life('life_expectancy')>=50)]
#                                                    ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
# Plotting Gap Minder Life Expectancy
import matplotlib.pyplot as plt
df_3[2016].hist()
plt.savefig('histo.png')

# %%
# Plotting Gap Minder Life Expectance with features
plt.title('Life Expectancy in 2016')
plt.xlabel('Value')
plt.ylabel('Frequency')
df_3[2016].hist(facecolor='#ff0000',
alpha=0.75,
histtype='bar')
plt.savefig('histo.png', dpi=150)

# %%
df_2 = df_2[['1950','1955', '2000']]
df_22 = df_2.loc[['Germany', 'India', 'Bulgaria', 'Kenya']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-178-1f6f49e0feb6> in <module>
# ----> 1 df_2 = df_2[['1950','1955', '2000']]
#       2 df_22 = df_2.loc[['Germany', 'India', 'Bulgaria', 'Kenya']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
# ...

# %%
# Plotting Fertility Rate
figsize=(5,7)
df_22.plot.bar()
plt.savefig('bars.png')

# %%
pd.merge(df_3, df_22, how='right',on='Life expectancy','Total fertility rate')
# Out:
#   File "<ipython-input-180-fd8425686de9>", line 1
#     pd.merge(df_3, df_22, how='right',on='Life expectancy','Total fertility rate')
#                                                            ^
# SyntaxError: positional argument follows keyword argument
