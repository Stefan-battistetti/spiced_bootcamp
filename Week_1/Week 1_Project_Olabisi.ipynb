# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
##Read in data from multiple sources
fert = pd.read_csv('gapminder_total_fertility.csv', index_col = 0)
fert.head()
###popu = pd.read_excel('gapminder_population.xlsx')
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %%
##check the shape of both tables
fert.shape
# Out:
# (260, 216)

# %%
life = pd.read_excel('gapminder_lifeexpectancy.xlsx', index_col=0)
life.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# ...

# %%
##check the shape of both tables
life.shape
# Out:
# (260, 217)

# %%
###Take a look at the columns of both tables:
fert.columns
###fert column are str
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
###Take a look at the columns of both tables:
life.columns
####life columns are integers
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
####convert the fert column to interger for merging with life
fert.columns = fert.columns.astype(int)

# %%
### check the fert columns
fert.columns
###changed to interger
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
####check the index of the life and column
fert.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'Åland'],
#       dtype='object', name='Total fertility rate', length=260)

# %%
####chnage the index name to country
fert.index.name = 'country'

# %%
fert.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Vietnam', 'Virgin Islands (U.S.)', 'North Yemen (former)',
#        'South Yemen (former)', 'Yemen', 'Yugoslavia', 'Zambia', 'Zimbabwe',
#        'Åland', 'Åland'],
#       dtype='object', name='country', length=260)

# %% [markdown]
# Convert the tables (life and fert)into long table

# %%
###using the reset funtion,
##fert table
fert.reset_index(inplace=True)

# %%
fert
# Out:
#                    country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0                 Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2    Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                  Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                  Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ..                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 255             Yugoslavia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256                 Zambia  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# 257               Zimbabwe  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# 258                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 259                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
fert.columns
# Out:
# Index(['country',      1800,      1801,      1802,      1803,      1804,
#             1805,      1806,      1807,      1808,
#        ...
#             2006,      2007,      2008,      2009,      2010,      2011,
#             2012,      2013,      2014,      2015],
#       dtype='object', length=217)

# %%
fert_melt = fert.melt(id_vars='country', var_name='year', value_name='fertility_rate')

# %%
fert_melt
# Out:
#                      country  year  fertility_rate
# 0                   Abkhazia  1800             NaN
# 1                Afghanistan  1800            7.00
# 2      Akrotiri and Dhekelia  1800             NaN
# 3                    Albania  1800            4.60
# 4                    Algeria  1800            6.99
# ...                      ...   ...             ...
# 56155             Yugoslavia  2015             NaN
# 56156                 Zambia  2015            5.59
# 56157               Zimbabwe  2015            3.35
# 56158                  Åland  2015             NaN
# 56159                  Åland  2015             NaN
#
# [56160 rows x 3 columns]

# %%
##change life expantncy to country
life.index.name = 'country'
life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# country
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
###reset the index
life.reset_index(inplace=True)
life
# Out:
#                    country   1800   1801   1802   1803   1804   1805   1806  \
# 0                 Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1              Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2    Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                  Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                  Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ..                     ...    ...    ...    ...    ...    ...    ...    ...
# 255             Yugoslavia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 256                 Zambia  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# 257               Zimbabwe  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# 258                  Åland    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 259            South Sudan  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
life_melt= life.melt(id_vars='country', var_name='year', value_name='life expectancy')
life_melt
# Out:
#                      country  year  life expectancy
# 0                   Abkhazia  1800              NaN
# 1                Afghanistan  1800            28.21
# 2      Akrotiri and Dhekelia  1800              NaN
# 3                    Albania  1800            35.40
# 4                    Algeria  1800            28.82
# ...                      ...   ...              ...
# 56415             Yugoslavia  2016              NaN
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56418                  Åland  2016              NaN
# 56419            South Sudan  2016            56.10
#
# [56420 rows x 3 columns]

# %%
###import population data
population = pd.read_excel('gapminder_population.xlsx', index_col=0, nrows=260)
population.head()
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
# ...

# %%
population.shape
# Out:
# (260, 81)

# %%
###check pop columns
population.columns
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %%
population.index.name='country'

# %%
population
# Out:
#                             1800       1810       1820       1830       1840  \
# country
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
# ...                          ...        ...        ...        ...        ...
# Yugoslavia                   NaN        NaN        NaN        NaN        NaN
# Zambia                  747000.0   747000.0   747000.0   747000.0   747000.0
# Zimbabwe               1085814.0  1085814.0  1106634.0  1167259.0  1253642.0
# Åland                        NaN        NaN        NaN        NaN        NaN
# South Sudan            1027378.0  1041076.0  1063732.0  1103246.0  1153401.0
#
# ...

# %%
population.reset_index(inplace=True)

# %%
population
# Out:
#                    country       1800       1810       1820       1830  \
# 0                 Abkhazia        NaN        NaN        NaN        NaN
# 1              Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0
# 2    Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                  Albania   410445.0   423591.0   438671.0   457234.0
# 4                  Algeria  2503218.0  2595056.0  2713079.0  2880355.0
# ..                     ...        ...        ...        ...        ...
# 255             Yugoslavia        NaN        NaN        NaN        NaN
# 256                 Zambia   747000.0   747000.0   747000.0   747000.0
# 257               Zimbabwe  1085814.0  1085814.0  1106634.0  1167259.0
# 258                  Åland        NaN        NaN        NaN        NaN
# 259            South Sudan  1027378.0  1041076.0  1063732.0  1103246.0
#
#           1840       1850       1860       1870       1880  ...        2006  \
# ...

# %%
population_melt = population.melt(id_vars='country', var_name='year', value_name='population')
population_melt
# Out:
#                      country  year  population
# 0                   Abkhazia  1800         NaN
# 1                Afghanistan  1800   3280000.0
# 2      Akrotiri and Dhekelia  1800         NaN
# 3                    Albania  1800    410445.0
# 4                    Algeria  1800   2503218.0
# ...                      ...   ...         ...
# 21055             Yugoslavia  2015         NaN
# 21056                 Zambia  2015  16211767.0
# 21057               Zimbabwe  2015  15602751.0
# 21058                  Åland  2015         NaN
# 21059            South Sudan  2015  12339812.0
#
# [21060 rows x 3 columns]

# %%
df_mg1 = fert_melt.merge(population_melt)

# %%
df_mg1
# Out:
#                      country  year  fertility_rate  population
# 0                   Abkhazia  1800             NaN         NaN
# 1                Afghanistan  1800            7.00   3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN         NaN
# 3                    Albania  1800            4.60    410445.0
# 4                    Algeria  1800            6.99   2503218.0
# ...                      ...   ...             ...         ...
# 20974             Yugoslavia  2015             NaN         NaN
# 20975                 Zambia  2015            5.59  16211767.0
# 20976               Zimbabwe  2015            3.35  15602751.0
# 20977                  Åland  2015             NaN         NaN
# 20978                  Åland  2015             NaN         NaN
#
# [20979 rows x 4 columns]

# %%
df_all=df_mg1.merge(life_melt)
df_all
# Out:
#                      country  year  fertility_rate  population  \
# 0                   Abkhazia  1800             NaN         NaN
# 1                Afghanistan  1800            7.00   3280000.0
# 2      Akrotiri and Dhekelia  1800             NaN         NaN
# 3                    Albania  1800            4.60    410445.0
# 4                    Algeria  1800            6.99   2503218.0
# ...                      ...   ...             ...         ...
# 20974             Yugoslavia  2015             NaN         NaN
# 20975                 Zambia  2015            5.59  16211767.0
# 20976               Zimbabwe  2015            3.35  15602751.0
# 20977                  Åland  2015             NaN         NaN
# 20978                  Åland  2015             NaN         NaN
#
#        life expectancy
# 0                  NaN
# 1                28.21
# 2                  NaN
# 3                35.40
# 4                28.82
# ...                ...
# 20974              NaN
# ...

# %%
df_all = df_all.dropna()
df_all
# Out:
#                      country  year  fertility_rate  population  \
# 1                Afghanistan  1800            7.00   3280000.0
# 3                    Albania  1800            4.60    410445.0
# 4                    Algeria  1800            6.99   2503218.0
# 7                     Angola  1800            6.93   1567028.0
# 9        Antigua and Barbuda  1800            5.00     37000.0
# ...                      ...   ...             ...         ...
# 20969                Vietnam  2015            1.70  93447601.0
# 20970  Virgin Islands (U.S.)  2015            2.45    106291.0
# 20973                  Yemen  2015            3.83  26832215.0
# 20975                 Zambia  2015            5.59  16211767.0
# 20976               Zimbabwe  2015            3.35  15602751.0
#
#        life expectancy
# 1                28.21
# 3                35.40
# 4                28.82
# 7                26.98
# 9                33.54
# ...                ...
# 20969            75.40
# ...

# %%
df_all
# Out:
#                      country  year  fertility_rate  population  \
# 1                Afghanistan  1800            7.00   3280000.0
# 3                    Albania  1800            4.60    410445.0
# 4                    Algeria  1800            6.99   2503218.0
# 7                     Angola  1800            6.93   1567028.0
# 9        Antigua and Barbuda  1800            5.00     37000.0
# ...                      ...   ...             ...         ...
# 20969                Vietnam  2015            1.70  93447601.0
# 20970  Virgin Islands (U.S.)  2015            2.45    106291.0
# 20973                  Yemen  2015            3.83  26832215.0
# 20975                 Zambia  2015            5.59  16211767.0
# 20976               Zimbabwe  2015            3.35  15602751.0
#
#        life expectancy
# 1                28.21
# 3                35.40
# 4                28.82
# 7                26.98
# 9                33.54
# ...                ...
# 20969            75.40
# ...

# %%
###create a subset of the merged data
df_2015 = df_all.loc[df_all['year']==2015]
df_2015
# Out:
#                      country  year  fertility_rate  population  \
# 20721            Afghanistan  2015            4.47  32526562.0
# 20723                Albania  2015            1.78   2896679.0
# 20724                Algeria  2015            2.71  39666519.0
# 20727                 Angola  2015            5.65  25021974.0
# 20729    Antigua and Barbuda  2015            2.06     91818.0
# ...                      ...   ...             ...         ...
# 20969                Vietnam  2015            1.70  93447601.0
# 20970  Virgin Islands (U.S.)  2015            2.45    106291.0
# 20973                  Yemen  2015            3.83  26832215.0
# 20975                 Zambia  2015            5.59  16211767.0
# 20976               Zimbabwe  2015            3.35  15602751.0
#
#        life expectancy
# 20721             53.8
# 20723             78.0
# 20724             76.4
# 20727             59.6
# 20729             76.4
# ...                ...
# 20969             75.4
# ...

# %%
###create scatter plot
sns.scatterplot(x='life expectancy', y='fertility_rate', data=df_2015, alpha=0.6)

plt.savefig('fil_2015.png')

# %%
df_all
# Out:
#                      country  year  fertility_rate  population  \
# 1                Afghanistan  1800            7.00   3280000.0
# 3                    Albania  1800            4.60    410445.0
# 4                    Algeria  1800            6.99   2503218.0
# 7                     Angola  1800            6.93   1567028.0
# 9        Antigua and Barbuda  1800            5.00     37000.0
# ...                      ...   ...             ...         ...
# 20969                Vietnam  2015            1.70  93447601.0
# 20970  Virgin Islands (U.S.)  2015            2.45    106291.0
# 20973                  Yemen  2015            3.83  26832215.0
# 20975                 Zambia  2015            5.59  16211767.0
# 20976               Zimbabwe  2015            3.35  15602751.0
#
#        life expectancy
# 1                28.21
# 3                35.40
# 4                28.82
# 7                26.98
# 9                33.54
# ...                ...
# 20969            75.40
# ...

# %%
xmin = df_all['life expectancy'].min()
xmax = df_all['life expectancy'].max()
ymin = df_all['fertility_rate'].min()
ymax = df_all['fertility_rate'].max()

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16230 entries, 1 to 20976
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          16230 non-null  object
#  1   year             16230 non-null  object
#  2   fertility_rate   16230 non-null  float64
#  3   population       16230 non-null  float64
#  4   life expectancy  16230 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 760.8+ KB

# %%
df_all['year'] = df_all['year'].astype(int)
# Out:
# <ipython-input-46-7cf3fa5bd886>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all['year'] = df_all['year'].astype(int)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16230 entries, 1 to 20976
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          16230 non-null  object
#  1   year             16230 non-null  int32
#  2   fertility_rate   16230 non-null  float64
#  3   population       16230 non-null  float64
#  4   life expectancy  16230 non-null  float64
# dtypes: float64(3), int32(1), object(1)
# memory usage: 697.4+ KB

# %%
for i in range(1960,2015):
    df_sub = df_all.loc[df_all['year']==i]
    ###print(df_sub.shape)
    sns.scatterplot(x='life expectancy', y='fertility_rate',
                    size='population', hue= 'country', sizes = (30, 400), legend=False, 
                    data=df_sub, alpha=0.6)
    plt.axis = ((xmin, xmax, ymin, ymax))
    plt.savefig('lifeexp_' + str(i)+'.png')
    plt.close()

# %%
import imageio
images = []

for r in range(1960,2015):
    filename = 'lifeexp_{}.png'.format(r)
    images.append(imageio.imread(filename))
imageio.mimsave('output.gif', images, fps=20)
