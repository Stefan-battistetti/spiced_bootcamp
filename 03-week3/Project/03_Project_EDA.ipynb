# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_orig = pd.read_csv('../data/train.csv',index_col=0, parse_dates=True)

# %%
df_orig.head(3)
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16
# 2011-01-01 01:00:00        80        0.0       8          32     40
# 2011-01-01 02:00:00        80        0.0       5          27     32

# %%
df_orig.shape
# Out:
# (10886, 11)

# %%
df_orig.index.min(), df_orig.index.max()
# Out:
# (Timestamp('2011-01-01 00:00:00'), Timestamp('2012-12-19 23:00:00'))

# %%
downdf = df_orig.resample('M').mean()

# %%
downdf['2011'].shape
# Out:
# <ipython-input-21-0a56e4179863>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   downdf['2011'].shape
# (12, 11)

# %%
downdf['count']['2011'].plot(figsize=(15, 8))
downdf['count']['2012'].plot(figsize=(15, 8))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
.plot(y = ['count'])
downdf['2012'].plot(y = ['count'])
# Out:
# <ipython-input-15-9bae5c7bd5cc>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   downdf['2011'].plot(y = ['count'])
# <ipython-input-15-9bae5c7bd5cc>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   downdf['2012'].plot(y = ['count'])
# <AxesSubplot:xlabel='datetime'>

# %%
df_orig.hist('count', 'workingday')
df_orig.hist('casual', 'workingday')
df_orig.hist('registered', 'workingday')
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %%
fig, axs = plt.subplots(3)

axs[0].hist(df_orig['casual'], df_orig['workingday'])
axs[1].scatter(df_orig['registered'], df_orig['workingday'])
axs[2].scatter(df_orig['count'], df_orig['workingday'])

axs[0].set_xticklabels([])
axs[1].set_xticklabels([])
#axs[2].set_xticklabels([])

#plt.scatter(df_orig['casual'], df_orig['workingday'])
#plt.scatter(df_orig['count'], df_orig['workingday'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-c931a37c4e3e> in <module>
#       1 fig, axs = plt.subplots(3)
#       2
# ----> 3 axs[0].hist(df_orig['casual'], df_orig['workingday'])
#       4 axs[1].scatter(df_orig['registered'], df_orig['workingday'])
#       5 axs[2].scatter(df_orig['count'], df_orig['workingday'])
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...
