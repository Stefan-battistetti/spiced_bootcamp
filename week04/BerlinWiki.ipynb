# %%
import requests
import re
from collections import Counter

# 1. retrieve the Berlin Wikipedia page
url = "https://en.wikipedia.org/wiki/Berlin"
response = requests.get(url)

# 2. check the status code
print(response)

# 3. store the html contents of the page
html = response.text

# 4. write the html contents to a file
with open ("berlin.html", "w") as f:
    f.write(html) 

# 5. remove all html tags
text = re.sub('<.*?>' ,'', html)

# 6. extract words
words = re.findall('[a-zA-Z]+', text)

# 7. remove words with less than 6 characters
long_words_1 =  re.sub(r'\b\w{1,6}\b', ' ', text)
long_words_2 = re.sub('\W', ' ',long_words_1)

# 8. create a Counter object from the long words
c = Counter(long_words_2.split())

# 9. print how often the word 'Berlin' occurs
print(len(re.findall(pattern='Berlin', string=text)))

# 10. print the 10 most common words
print(c.most_common(10))
# Out:
# <Response [200]>
# 753
# [('Retrieved', 225), ('Germany', 101), ('original', 85), ('Archived', 85), ('Brandenburg', 54), ('November', 48), ('largest', 46), ('February', 45), ('October', 41), ('December', 37)]

# %%
long_words_2
# Out:
# '        Wikipedia document documentElement className           wgBreakFrames     wgSeparatorTransformTable           wgDigitTransformTable           wgDefaultDateFormat       wgMonthNames       January   February                           September   October   November   December    wgRequestId   bbd3a583       8523763bbfdb   wgCSPNonce     wgCanonicalNamespace      wgCanonicalSpecialPageName     wgNamespaceNumber     wgPageName       wgTitle       wgCurRevisionId  1063853880  wgRevisionId  1063853880  wgArticleId     wgIsArticle     wgIsRedirect     wgAction       wgUserName     wgUserGroups         wgCategories        language sources            multiple    authors             original     unknown     articles     external     Articles     external           Webarchive template wayback     Articles     external     December      Articles   permanently   external         language sources       Articles     description     description   different   Wikidata     American English   October       Wikipedia articles written   American English           September         infobox settlement     settlement     Coordinates   Wikidata   Articles     microformats     articles   unsourced statements   Articles   unsourced statements         Articles containing potentially   statements         articles containing potentially   statements   Articles   unsourced statements             multiple             Articles containing   language     Articles   unsourced statements   January     Articles containing potentially   statements       Wikipedia articles       updating   January       Wikipedia articles       updating    Articles containing potentially   statements       Articles containing potentially   statements                 authors     Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles   WORLDCATID identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles   MusicBrainz   identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles     identifiers   Articles   multiple identifiers         Kartographer extension           capitals   Capitals              Members     Hanseatic     Populated   established       century   Turkish communities outside       establishments               establishments           Germany    wgPageContentLanguage       wgPageContentModel   wikitext   wgRelevantPageName       wgRelevantArticleId     wgIsProbablyEditable     wgRelevantPageIsProbablyEditable     wgRestrictionEdit      wgRestrictionMove      wgFlaggedRevsParams                        wgPopupsFlags     wgVisualEditor    pageLanguageCode       pageLanguageDir       pageVariantFallbacks        wgMFDisplayWikibaseDescriptions                watchlist     tagline      wgWMESchemaEditAttemptStepOversample     wgWMEPageLength     wgNoticeProject   wikipedia   wgMediaViewerOnClick     wgMediaViewerEnabledByDefault     wgULSCurrentAutonym   English   wgKartographerLiveData     _5c3cdadd0a60372bea4be4576608aad14b0febba         ExternalData   service   geoshape             wikimedia   geoshape getgeojson   u0026ids     properties              opacity                                   wgCoordinates         519999999999996       405000000000001   wgEditSubmitButtonLabelPublish     wgCentralAuthMobileDomain     wgULSPosition   interlanguage   wgULSisCompactLinksEnabled     wgWikibaseItemId       wgGENewcomerTasksGuidanceEnabled     wgGEAskQuestionEnabled     wgGELinkRecommendationsFrontendEnabled     RLSTATE     globalCssJs                                 globalCssJs                   options   loading     kartographer                     mediawiki   gallery                         makeCollapsible  ...

# %%
text
# Out:
# '\n\n\n\nBerlin - Wikipedia\ndocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"bbd3a583-2216-4b96-841b-8523763bbfdb","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Berlin","wgTitle":"Berlin","wgCurRevisionId":1063853880,"wgRevisionId":1063853880,"wgArticleId":3354,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 German-language sources (de)","CS1 maint: multiple names: authors list","CS1 maint: bot: original URL status unknown","All articles with dead external links","Articles with dead external links from July 2019","Webarchive template wayback links","Articles with dead external links from December 2021",\n"Articles with permanently dead external links","CS1 French-language sources (fr)","Articles with short description","Short description is different from Wikidata","Use American English from October 2020","All Wikipedia articles written in American English","Use dmy dates from September 2020","Pages using infobox settlement with bad settlement type","Coordinates on Wikidata","Articles with hAudio microformats","All articles with unsourced statements","Articles with unsourced statements from April 2019","Articles containing potentially dated statements from 2019","All articles containing potentially dated statements","Articles with unsourced statements from April 2020","Pages using multiple image with manual scaled images","Articles containing German-language text","Articles with unsourced statements from January 2021","Articles containing potentially dated statements from 2015","Wikipedia articles in need of updating from January 2021","All Wikipedia articles in need of updating",\n"Articles containing potentially dated statements from 2014","Articles containing potentially dated statements from 2011","CS1 maint: extra text: authors list","Articles with GND identifiers","Articles with ISNI identifiers","Articles with VIAF identifiers","Articles with WORLDCATID identifiers","Articles with BIBSYS identifiers","Articles with BNE identifiers","Articles with BNF identifiers","Articles with EMU identifiers","Articles with LCCN identifiers","Articles with NDL identifiers","Articles with NKC identifiers","Articles with NLI identifiers","Articles with NLK identifiers","Articles with SELIBR identifiers","Articles with FAST identifiers","Articles with HDS identifiers","Articles with MusicBrainz area identifiers","Articles with NARA identifiers","Articles with RISM identifiers","Articles with RERO identifiers","Articles with SUDOC identifiers","Articles with multiple identifiers","Pages using the Kartographer extension","Berlin","German state capitals","Capitals in Europe",\n"City-states","Members of the Hanseatic League","Populated places established in the 13th century","Turkish communities outside Turkey","1230s establishments in the Holy Roman Empire","1237 establishments in Europe","States of Germany"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Berlin","wgRelevantArticleId":3354,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":-1}}},"wgPopupsFlags":10,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":200000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgULSCurrentAutonym":"English","wgKartographerLiveData":{\n"_5c3cdadd0a60372be ...
