# %%
url = 'https://www.eventbrite.com/d/germany--berlin/music--events/'

# %%
import requests

# %%
response = requests.get(url)
eventbrite = response.text
type(eventbrite)
# Out:
# str

# %%
eventbrite[:100]
# Out:
# '<!DOCTYPE html>\n\n\n\n\n\n\n\n<html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#" la'

# %%
from bs4 import BeautifulSoup

# %%
eventbrite_soup = BeautifulSoup(eventbrite, 'html.parser')

# %%
print(eventbrite_soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-us" translate="no" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
# <head>
# <title>
#     Berlin, Germany Music Events | Eventbrite
# </title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="en" http-equiv="Content-Language">
# <link href="https://cdn.evbstatic.com/s3-build/311051-rc2022-01-05_16.04-9f7bea8/django/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://cdn.evbstatic.com/s3-build/311051-rc2022-01-05_16.04-9f7bea8/django/images/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
# <link href="https://cdn.evbstatic.com/s3-build/311051-rc2022-01-05_16.04-9f7bea8/django/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# ...

# %%
eventbrite_soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en-us" translate="no" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">\n <head>\n  <title>\n   Berlin, Germany Music Events | Eventbrite\n  </title>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  <meta content="en" http-equiv="Content-Language">\n   <link href="https://cdn.evbstatic.com/s3-build/311051-rc2022-01-05_16.04-9f7bea8/django/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n   <link href="https://cdn.evbstatic.com/s3-build/311051-rc2022-01-05_16.04-9f7bea8/django/images/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>\n   <link href="https://cdn.evbstatic.com/s3-build/311051-rc2022-01-05_16.04-9f7bea8/django/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>\n   <link href="https://cdn.evbstatic.com/s3-build/311051-rc2022-01-05_16.04-9f7bea8/django/images/favicons/android-chrome-192x192.png
# ...

# %%
eventbrite_soup.head.title
# Out:
# <title>
#     Berlin, Germany Music Events | Eventbrite
# </title>

# %%
eventbrite_soup.head.title.text
# Out:
# '\n    Berlin, Germany Music Events | Eventbrite\n'

# %%
eventbrite_soup.title.name
# Out:
# 'title'

# %%
eventbrite_soup.body.find_all('h3')
# Out:
# [<h3 class="eds-event-card-content__title eds-text-color--ui-800 eds-text-bl eds-text-weight--heavy"><div data-spec="event-card__formatted-name"><div class="eds-is-hidden-accessible">LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN</div><div aria-hidden="true" class="eds-event-card__formatted-name--is-clamped eds-event-card__formatted-name--is-clamped-three eds-text-weight--heavy" data-spec="event-card__formatted-name--content" role="presentation">LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN</div></div></h3>,
# ...

# %%
[t.text for t in eventbrite_soup.find_all('h3', class_='eds-text-weight--heavy')]
# Out:
# ['LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLINLASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN',
#  'LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLINLASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN',
#  'Satantango liveSatantango live',
#  'Satantango liveSatantango live',
#  'MONOM + Vorspiel / transmediale & CTM presents: Dripping PointMONOM + Vorspiel / transmediale & CTM presents: Dripping Point',
#  'MONOM + Vorspiel / transmediale & CTM presents: Dripping PointMONOM + Vorspiel / transmediale & CTM presents: Dripping Point',
#  'Chaosbay + Sentryturn // Cassiopeia, BerlinChaosbay + Sentryturn // Cassiopeia, Berlin',
#  'Chaosbay + Sentryturn // Cassiopeia, BerlinChaosbay + Sentryturn // Cassiopeia, Berlin',
#  'Dark Rave meets Devil  Rave / Timo Mandl (Verschoben)Dark Rave meets Devil  Rave / Timo Mandl (Verschoben)',
# ...

# %%
eventbrite_soup.find_all('h3', attrs={'class': 'eds-text-weight--heavy'})
# Out:
# [<h3 class="eds-event-card-content__title eds-text-color--ui-800 eds-text-bl eds-text-weight--heavy"><div data-spec="event-card__formatted-name"><div class="eds-is-hidden-accessible">LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN</div><div aria-hidden="true" class="eds-event-card__formatted-name--is-clamped eds-event-card__formatted-name--is-clamped-three eds-text-weight--heavy" data-spec="event-card__formatted-name--content" role="presentation">LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN</div></div></h3>,
# ...

# %%
for t in eventbrite_soup.find_all('h3', attrs={'class': 'eds-text-weight--heavy'}):
    print(t.text)
# Out:
# LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLINLASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN
# LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLINLASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN
# Satantango liveSatantango live
# Satantango liveSatantango live
# MONOM + Vorspiel / transmediale & CTM presents: Dripping PointMONOM + Vorspiel / transmediale & CTM presents: Dripping Point
# MONOM + Vorspiel / transmediale & CTM presents: Dripping PointMONOM + Vorspiel / transmediale & CTM presents: Dripping Point
# Chaosbay + Sentryturn // Cassiopeia, BerlinChaosbay + Sentryturn // Cassiopeia, Berlin
# Chaosbay + Sentryturn // Cassiopeia, BerlinChaosbay + Sentryturn // Cassiopeia, Berlin
# Dark Rave meets Devil  Rave / Timo Mandl (Verschoben)Dark Rave meets Devil  Rave / Timo Mandl (Verschoben)
# Dark Rave meets Devil  Rave / Timo Mandl (Verschoben)Dark Rave meets Devil  Rave / Timo Mandl (Verschoben)
# ...

# %%
eventbrite_soup.find(id='logo-wordmark-brand_svg__Fill-2')
# Out:
# <path d="M31.89 35.118l-9.364-22.84h6.57l5.932 15.49 5.982-15.49h6.57l-9.365 22.84z" id="logo-wordmark-brand_svg__Fill-2"></path>

# %%
eventbrite_soup.body.find(class_ = "eds-text-weight--heavy")
# Out:
# <h3 class="eds-event-card-content__title eds-text-color--ui-800 eds-text-bl eds-text-weight--heavy"><div data-spec="event-card__formatted-name"><div class="eds-is-hidden-accessible">LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN</div><div aria-hidden="true" class="eds-event-card__formatted-name--is-clamped eds-event-card__formatted-name--is-clamped-three eds-text-weight--heavy" data-spec="event-card__formatted-name--content" role="presentation">LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN</div></div></h3>

# %%
eventbrite_soup.body.find(class_ = "eds-event-card-content__title").h3

# %%
eventbrite_soup.body.find(class_ = "eds-event-card-content__title").find(class_="eds-text-weight--heavy").text #chains
# Out:
# 'LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN'

# %%
ds_curriculum = eventbrite_soup.find_all(class_ = 'eds-event-card-content__title') 
# find_all returns a list like object called "Result Set"

# %%
ds_curriculum[0]
# Out:
# <h3 class="eds-event-card-content__title eds-text-color--ui-800 eds-text-bl eds-text-weight--heavy"><div data-spec="event-card__formatted-name"><div class="eds-is-hidden-accessible">LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN</div><div aria-hidden="true" class="eds-event-card__formatted-name--is-clamped eds-event-card__formatted-name--is-clamped-three eds-text-weight--heavy" data-spec="event-card__formatted-name--content" role="presentation">LASS ZOCKEN • INDIE vs HIPHOP • NEW DATE  26.02.22  • LIDO BERLIN</div></div></h3>

# %%
ds_curriculum[0].h3

# %%
topic = []
description = []

for items in ds_curriculum:
    topic.append(items.text)
    description.append(items.find(class_ = "eds-event-card-content__title").text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-85e0686a55f6> in <module>()
#       4 for items in ds_curriculum:
#       5     topic.append(items.text)
# ----> 6     description.append(items.find(class_ = "eds-event-card-content__title").text)
#
# AttributeError: 'NoneType' object has no attribute 'text'
