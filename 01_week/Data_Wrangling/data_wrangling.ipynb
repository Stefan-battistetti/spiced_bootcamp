# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import os

# %%
# !ls
# Out:
# concat.png             merge_leftright.png    penguins_gentoo.csv
# data_wrangling.ipynb   penguins_adelie.csv    sex_data_penguins.csv
# merge.png              penguins_chinstrap.csv

# %%
os.listdir()
# Out:
# ['sex_data_penguins.csv',
#  'merge_leftright.png',
#  'merge.png',
#  'penguins_chinstrap.csv',
#  'concat.png',
#  'data_wrangling.ipynb',
#  'penguins_gentoo.csv',
#  '.ipynb_checkpoints',
#  'penguins_adelie.csv']

# %%
df_list = []
for file in os.listdir():
    if file.startswith('penguins'):
        df = pd.read_csv(file)
        df_list.append(df)

# %%
df_list[1].head()
# Out:
#   studyName  Sample Number Species Sample ID  Region  Island Individual ID  \
# 0   PAL0708              1  Gentoo       G_1  Anvers  Biscoe         N31A1
# 1   PAL0708              2  Gentoo       G_2  Anvers  Biscoe         N31A2
# 2   PAL0708              3  Gentoo       G_3  Anvers  Biscoe         N32A1
# 3   PAL0708              4  Gentoo       G_4  Anvers  Biscoe         N32A2
# 4   PAL0708              5  Gentoo       G_5  Anvers  Biscoe         N33A1
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                46.1               13.2                211.0         4500.0
# 1                50.0               16.3                230.0         5700.0
# 2                48.7               14.1                210.0         4450.0
# 3                50.0               15.2                218.0         5700.0
# 4                47.6               14.5                215.0         5400.0
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df_all = pd.concat(df_list).reset_index(drop=True)

# %%
df_all.shape
# Out:
# (344, 12)

# %%
df_all.reset_index()
# Out:
#      index studyName  Sample Number    Species Sample ID  Region Island  \
# 0        0   PAL0708              1  Chinstrap       C_1  Anvers  Dream
# 1        1   PAL0708              2  Chinstrap       C_2  Anvers  Dream
# 2        2   PAL0708              3  Chinstrap       C_3  Anvers  Dream
# 3        3   PAL0708              4  Chinstrap       C_4  Anvers  Dream
# 4        4   PAL0708              5  Chinstrap       C_5  Anvers  Dream
# ..     ...       ...            ...        ...       ...     ...    ...
# 339    339   PAL0910            148     Adelie     A_148  Anvers  Dream
# 340    340   PAL0910            149     Adelie     A_149  Anvers  Dream
# 341    341   PAL0910            150     Adelie     A_150  Anvers  Dream
# 342    342   PAL0910            151     Adelie     A_151  Anvers  Dream
# 343    343   PAL0910            152     Adelie     A_152  Anvers  Dream
#
#     Individual ID  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0           N61A1                46.5               17.9                192.0
# 1           N61A2                50.0               19.5                196.0
# 2           N62A1                51.3               19.2                193.0
# 3           N62A2                45.4               18.7                188.0
# 4           N64A1                52.7               19.8                197.0
# ..            ...                 ...                ...                  ...
# 339         N83A2                36.6               18.4                184.0
# 340         N84A1                36.0               17.8                195.0
# 341         N84A2                37.8               18.1                193.0
# 342         N85A1                36.0               17.1                187.0
# 343         N85A2                41.5               18.5                201.0
#
#      Body Mass (g) Comments
# 0           3500.0      NaN
# 1           3900.0      NaN
# 2           3650.0      NaN
# 3           3525.0      NaN
# 4           3725.0      NaN
# ..             ...      ...
# 339         3475.0      NaN
# 340         3450.0      NaN
# 341         3750.0      NaN
# 342         3700.0      NaN
# 343         4000.0      NaN
#
# [344 rows x 13 columns]

# %%
df_all.head()
# Out:
#   studyName  Sample Number    Species Sample ID  Region Island Individual ID  \
# 0   PAL0708              1  Chinstrap       C_1  Anvers  Dream         N61A1
# 1   PAL0708              2  Chinstrap       C_2  Anvers  Dream         N61A2
# 2   PAL0708              3  Chinstrap       C_3  Anvers  Dream         N62A1
# 3   PAL0708              4  Chinstrap       C_4  Anvers  Dream         N62A2
# 4   PAL0708              5  Chinstrap       C_5  Anvers  Dream         N64A1
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                46.5               17.9                192.0         3500.0
# 1                50.0               19.5                196.0         3900.0
# 2                51.3               19.2                193.0         3650.0
# 3                45.4               18.7                188.0         3525.0
# 4                52.7               19.8                197.0         3725.0
#
#   Comments
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df_sex = pd.read_csv('sex_data_penguins.csv')
df_sex.head()
# Out:
#       Sex  Sample Number Species
# 0    MALE              1  Adelie
# 1  FEMALE              2  Adelie
# 2  FEMALE              3  Adelie
# 3     NaN              4  Adelie
# 4  FEMALE              5  Adelie

# %%
df_sex.shape
# Out:
# (344, 3)

# %%
df_sex['Sample Number'].nunique()
# Out:
# 152

# %%
df_all.iloc[12]
# Out:
# studyName                PAL0708
# Sample Number                 13
# Species                Chinstrap
# Sample ID                   C_13
# Region                    Anvers
# Island                     Dream
# Individual ID              N69A1
# Culmen Length (mm)          47.0
# Culmen Depth (mm)           17.3
# Flipper Length (mm)        185.0
# Body Mass (g)             3700.0
# Comments                     NaN
# Name: 12, dtype: object

# %%
df_all.head(3)
# Out:
#   studyName  Sample Number    Species Sample ID  Region Island Individual ID  \
# 0   PAL0708              1  Chinstrap       C_1  Anvers  Dream         N61A1
# 1   PAL0708              2  Chinstrap       C_2  Anvers  Dream         N61A2
# 2   PAL0708              3  Chinstrap       C_3  Anvers  Dream         N62A1
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                46.5               17.9                192.0         3500.0
# 1                50.0               19.5                196.0         3900.0
# 2                51.3               19.2                193.0         3650.0
#
#   Comments
# 0      NaN
# 1      NaN
# 2      NaN

# %%
df_all['Species'].str[0]
# Out:
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C
#       ..
# 339    A
# 340    A
# 341    A
# 342    A
# 343    A
# Name: Species, Length: 344, dtype: object

# %%
df_sex["Sample ID"]= df_sex['Species'].str[0]+"_"+df_sex['Sample Number'].astype(str)

# %%
df_sex.head()
# Out:
#       Sex  Sample Number Species Sample ID
# 0    MALE              1  Adelie       A_1
# 1  FEMALE              2  Adelie       A_2
# 2  FEMALE              3  Adelie       A_3
# 3     NaN              4  Adelie       A_4
# 4  FEMALE              5  Adelie       A_5

# %%
df_sex.drop(['Sample Number', 'Species'], axis=1,inplace=True)

# %%
df_sex
# Out:
#         Sex Sample ID
# 0      MALE       A_1
# 1    FEMALE       A_2
# 2    FEMALE       A_3
# 3       NaN       A_4
# 4    FEMALE       A_5
# ..      ...       ...
# 339     NaN     G_120
# 340  FEMALE     G_121
# 341    MALE     G_122
# 342  FEMALE     G_123
# 343    MALE     G_124
#
# [344 rows x 2 columns]

# %%
df_all.shape
# Out:
# (344, 12)

# %%
df_completed = pd.merge(df_all,df_sex,on='Sample ID')

# %%
df_completed.head()
# Out:
#   studyName  Sample Number    Species Sample ID  Region Island Individual ID  \
# 0   PAL0708              1  Chinstrap       C_1  Anvers  Dream         N61A1
# 1   PAL0708              2  Chinstrap       C_2  Anvers  Dream         N61A2
# 2   PAL0708              3  Chinstrap       C_3  Anvers  Dream         N62A1
# 3   PAL0708              4  Chinstrap       C_4  Anvers  Dream         N62A2
# 4   PAL0708              5  Chinstrap       C_5  Anvers  Dream         N64A1
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                46.5               17.9                192.0         3500.0
# 1                50.0               19.5                196.0         3900.0
# 2                51.3               19.2                193.0         3650.0
# 3                45.4               18.7                188.0         3525.0
# 4                52.7               19.8                197.0         3725.0
#
#   Comments     Sex
# 0      NaN  FEMALE
# 1      NaN    MALE
# 2      NaN    MALE
# 3      NaN  FEMALE
# 4      NaN    MALE

# %%
df_completed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344 entries, 0 to 343
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Sample ID            344 non-null    object
#  4   Region               344 non-null    object
#  5   Island               344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Culmen Length (mm)   342 non-null    float64
#  8   Culmen Depth (mm)    342 non-null    float64
#  9   Flipper Length (mm)  342 non-null    float64
#  10  Body Mass (g)        342 non-null    float64
#  11  Comments             26 non-null     object
#  12  Sex                  334 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 37.6+ KB

# %%
df.isna(), df.isnull()
# Out:
# (     studyName  Sample Number  Species  Sample ID  Region  Island  \
#  0        False          False    False      False   False   False
#  1        False          False    False      False   False   False
#  2        False          False    False      False   False   False
#  3        False          False    False      False   False   False
#  4        False          False    False      False   False   False
#  ..         ...            ...      ...        ...     ...     ...
#  147      False          False    False      False   False   False
#  148      False          False    False      False   False   False
#  149      False          False    False      False   False   False
#  150      False          False    False      False   False   False
#  151      False          False    False      False   False   False
#
#       Individual ID  Culmen Length (mm)  Culmen Depth (mm)  \
#  0            False               False              False
#  1            False               False              False
#  2            False               False              False
#  3            False                True               True
#  4            False               False              False
#  ..             ...                 ...                ...
#  147          False               False              False
#  148          False               False              False
#  149          False               False              False
#  150          False               False              False
#  151          False               False              False
#
#       Flipper Length (mm)  Body Mass (g)  Comments
#  0                  False          False     False
#  1                  False          False      True
#  2                  False          False      True
#  3                   True           True     False
#  4                  False          False      True
#  ..                   ...            ...       ...
#  147                False          False      True
#  148                False          False      True
#  149                False          False      True
#  150                False          False      True
#  151                False          False      True
#
#  [152 rows x 12 columns],
#       studyName  Sample Number  Species  Sample ID  Region  Island  \
#  0        False          False    False      False   False   False
#  1        False          False    False      False   False   False
#  2        False          False    False      False   False   False
#  3        False          False    False      False   False   False
#  4        False          False    False      False   False   False
#  ..         ...            ...      ...        ...     ...     ...
#  147      False          False    False      False   False   False
#  148      False          False    False      False   False   False
#  149      False          False    False      False   False   False
#  150      False          False    False      False   False   False
#  151      False          False    False      False   False   False
#
#       Individual ID  Culmen Length (mm)  Culmen Depth (mm)  \
#  0            False               False              False
#  1            False               False              False
#  2            False               False              False
#  3            False                True               True
#  4            False               False              False
#  ..             ...                 ...                ...
#  147          False               False              False
#  148          False               False              False
#  149          False               False              False
#  150          False               False              False
#  151          False               False              False
#
#       Flipper Length (mm)  Body Mass (g)  Comments
#  0                  False          False     False
#  1                  False          False      True
#  2                  False          False      True
#  3                   True           True     False
#  4                  False          False      True
#  ..                   ...            ...       ...
#  147                False          False      True
#  148                False          False      True
#  149                False          False      True
#  150                False          False      True
#  151                False          False      True
#
#  [152 rows x 12 columns])

# %%
df_completed.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Sample ID                0
# Region                   0
# Island                   0
# Individual ID            0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Comments               318
# Sex                     10
# dtype: int64

# %%
sns.heatmap(df_completed.isnull())
# Out:
# <AxesSubplot:>

# %%
df_completed.dropna(thresh=318,axis=1, inplace=True)

# %%
sns.heatmap(df_completed.isnull())
# Out:
# <AxesSubplot:>

# %%
df_completed['Culmen Depth (mm)'].fillna(value=df['Culmen Depth (mm)'].mean(), inplace=True)

# %%
df_completed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344 entries, 0 to 343
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Sample ID            344 non-null    object
#  4   Region               344 non-null    object
#  5   Island               344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Culmen Length (mm)   342 non-null    float64
#  8   Culmen Depth (mm)    344 non-null    float64
#  9   Flipper Length (mm)  342 non-null    float64
#  10  Body Mass (g)        342 non-null    float64
#  11  Sex                  334 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 34.9+ KB
