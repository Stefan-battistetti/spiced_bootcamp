# %%
import pandas as pd

# %%
df = pd.read_excel('gapminder_lifeexpectancy.xlsx', index_col=0)
df
# Out:
#                        1800.0  1801.0  1802.0  1803.0  1804.0  1805.0  1806.0  \
# Life expectancy
# Abkhazia                  NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Afghanistan             28.21   28.20   28.19   28.18   28.17   28.16   28.15
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Albania                 35.40   35.40   35.40   35.40   35.40   35.40   35.40
# Algeria                 28.82   28.82   28.82   28.82   28.82   28.82   28.82
# ...                       ...     ...     ...     ...     ...     ...     ...
# Yugoslavia                NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Zambia                  32.60   32.60   32.60   32.60   32.60   32.60   32.60
# Zimbabwe                33.70   33.70   33.70   33.70   33.70   33.70   33.70
# Åland                     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# South Sudan             26.67   26.67   26.67   26.67   26.67   26.67   26.67
#
# ...

# %%
df[[1950, 1975, 2000, 2015]]
# Out:
#                        1950.0  1975.0  2000.0  2015.0
# Life expectancy
# Abkhazia                  NaN     NaN     NaN     NaN
# Afghanistan             26.85   39.61    50.1    53.8
# Akrotiri and Dhekelia     NaN     NaN     NaN     NaN
# Albania                 54.48   69.77    74.7    78.0
# Algeria                 42.77   55.24    73.3    76.4
# ...                       ...     ...     ...     ...
# Yugoslavia                NaN     NaN     NaN     NaN
# Zambia                  42.85   56.70    44.8    56.7
# Zimbabwe                48.46   59.41    47.9    59.3
# Åland                     NaN     NaN    80.0     NaN
# South Sudan             28.14   42.93    54.4    56.1
#
# [260 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

df[2015].hist()
plt.savefig('histo.png')

# %%
df[2000].hist(bins=5, facecolor='#ff0000', alpha=0.75, histtype='bar')
df[1975].hist(bins=10)
df[1950].hist(bins=20)

plt.title('Histgram')
plt.xlabel('value')
plt.ylabel('frequency')

#plt.axis([0.0, 50.0, 0.0, 10.0])
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.savefig('histo.png', dpi=150)
