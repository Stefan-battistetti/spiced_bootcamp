# %%
import pandas as pd

# %%
fn = ('/insert/your/path/gapminder_total_fertility.csv')

# 1. Read a data file --> it was missing the pd
df = pd.read_csv('/content/gapminder_total_fertility.csv', index_col=0)
df
# Out:
#                        1800  1801  1802  1803  ...  2012  2013  2014  2015
# Total fertility rate                           ...
# Abkhazia                NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  ...  5.14  4.90  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  ...  1.76  1.77  1.78  1.78
# Algeria                6.99  6.99  6.99  6.99  ...  2.82  2.80  2.76  2.71
# ...                     ...   ...   ...   ...  ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  ...  5.73  5.69  5.64  5.59
# Zimbabwe               6.75  6.75  6.75  6.75  ...  3.56  3.49  3.41  3.35
# Åland                   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
#
# [260 rows x 216 columns]

# %%
# 2. Inspect the size of a DataFrame
#df.shape()
df.shape
# Out:
# (260, 216)

# %%
# 3. Convert column labels to integers
# axis=0 -> rows ; axis=1 -> columns
df.set_axis(df.columns.astype(int), axis=1, inplace=True)

# %%
# 4. Remove rows with missing values
#df.dropna()
df.dropna(inplace=True)
df
# Out:
#                        1800  1801  1802  1803  ...  2012  2013  2014  2015
# Total fertility rate                           ...
# Afghanistan            7.00  7.00  7.00  7.00  ...  5.14  4.90  4.68  4.47
# Albania                4.60  4.60  4.60  4.60  ...  1.76  1.77  1.78  1.78
# Algeria                6.99  6.99  6.99  6.99  ...  2.82  2.80  2.76  2.71
# Angola                 6.93  6.93  6.93  6.93  ...  5.98  5.86  5.75  5.65
# Antigua and Barbuda    5.00  5.00  4.99  4.99  ...  2.10  2.09  2.08  2.06
# ...                     ...   ...   ...   ...  ...   ...   ...   ...   ...
# Vietnam                4.70  4.70  4.70  4.70  ...  1.77  1.74  1.72  1.70
# Virgin Islands (U.S.)  5.55  5.55  5.55  5.55  ...  2.50  2.49  2.47  2.45
# Yemen                  6.88  6.88  6.88  6.88  ...  4.21  4.08  3.95  3.83
# Zambia                 6.71  6.71  6.71  6.71  ...  5.73  5.69  5.64  5.59
# Zimbabwe               6.75  6.75  6.75  6.75  ...  3.56  3.49  3.41  3.35
#
# [199 rows x 216 columns]

# %%
# 5. Inspect a single value
#df['Germany',2000]
df.loc['Germany'][2000]
# Out:
# 1.35

# %%
# 6. Calculate the mean of a column
#df.loc['Germany']

df[2000].mean()
# Out:
# 3.2499497487437217

# %%
# 7. Filter rows with values in given range
#df[df[2000].between(6.0, 6.5)] --> table with all rows
df[df[2000].between(6.0, 6.5)][2000]
# Out:
# Total fertility rate
# Malawi     6.25
# Nigeria    6.10
# Yemen      6.36
# Zambia     6.07
# Name: 2000, dtype: float64

# %%
# 8. Mean fertility over time
#df.plot().mean()
df.mean().plot()
#ax.plt()

# %%
# 9. Three countries over time
df.loc[['Germany', 'Sweden', 'Kenya']].transpose().plot()

# %%
# 10. Countries with most frequent initials
df.reset_index()['Total fertility rate'].str[0].value_counts().head().plot().bar
# Out:
# <bound method Axes.bar of <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b37b15750>>
