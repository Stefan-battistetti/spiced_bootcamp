# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import NMF

# %% [markdown]
# ### Define a class for pre-processing and make DataFrame from URL from each artist

# %%
class lyric:
    def artist(url):
        soup = BeautifulSoup(requests.get(url).text,'html.parser')
        table = soup.find('table', {'class':'tdata'})
        href_links = []
        lyric_links=[]
        lyrics=[] 
        for link in table.findAll('a'):
            href_links.append(link.get('href'))

        for i in href_links:
            if ([i.startswith('/sublyric/'),i.startswith('/lyric-lf/')]):
                i = 'https://www.lyrics.com' + i
                lyric_links.append(i)

        for t in lyric_links:
            i = (BeautifulSoup(requests.get(t).text,'html.parser').find(id='lyric-body-text')).get_text()
            lyrics.append(i)
        df = pd.DataFrame(lyrics)
        df.rename(columns={0: 'lyric'}, inplace=True)
        df.drop_duplicates(subset ='lyric',keep = 'first' , inplace = True, ignore_index=True)
        df['lyric']=(df['lyric'].str.replace('\W', ' ')).str.lower()
        return df

# %%
Billie_Rogue = lyric
Billie_Rogue = Billie_Rogue.artist('https://www.lyrics.com/artist/Billie-Rogue/2137945805')
# Out:
# <ipython-input-15-ff8d15db5abb>:22: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['lyric']=(df['lyric'].str.replace('\W', ' ')).str.lower()

# %%
K_Ray = lyric
K_Ray = K_Ray.artist('https://www.lyrics.com/artist/K.-Ray/2137906147')
# Out:
# <ipython-input-15-ff8d15db5abb>:22: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['lyric']=(df['lyric'].str.replace('\W', ' ')).str.lower()

# %% [markdown]
# ### Add a column to each DataFrame specifying artist category + Concatinate both

# %%
Billie_Rogue.info() , K_Ray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lyric   4 non-null      object
# dtypes: object(1)
# memory usage: 160.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lyric   12 non-null     object
# dtypes: object(1)
# memory usage: 224.0+ bytes
# (None, None)

# %%
frames = [Billie_Rogue, K_Ray]
df = pd.concat(frames, ignore_index=True)
df['artist'] = ['Billie_Rogue'] * 4 + ['K_Ray'] * 12

# %% [markdown]
# ### Split the DataFrame into Train & Test

# %%
X_train, X_test, y_train, y_test = train_test_split(df['lyric'], df['artist'], train_size=0.8, random_state=10)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((12,), (4,), (12,), (4,))

# %% [markdown]
# ### Pre_Processing using TFIDF & Classification Model using Naive Bayes via Pipeline

# %%
steps = [('tf-idf', TfidfVectorizer(stop_words=None)),
         
          ('NB', MultinomialNB())
        ]

pipeline = Pipeline(steps)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tf-idf', TfidfVectorizer()), ('NB', MultinomialNB())])

# %%
pipeline.score(X_test, y_test)
# Out:
# 0.75

# %%
pipeline.predict(["The child Must remain"])
# Out:
# array(['K_Ray'], dtype='<U12')

# %% [markdown]
# ### Using NMF as decomposition matrix algorithms for topic extraction

# %%
vectorizer_tf = TfidfVectorizer(stop_words='english')
Y = vectorizer_tf.fit_transform(df['lyric'])
tfidf = pd.DataFrame(Y.toarray(),columns=vectorizer_tf.get_feature_names())

# %%
model = NMF(n_components=16, init='random', random_state=0)
W = model.fit_transform(tfidf)
H = model.components_

# %%
components_df = pd.DataFrame(model.components_, columns=vectorizer_tf.get_feature_names(), index=['Billie_Rogue'] * 4 + ['K_Ray'] * 12)
components_df
# Out:
#                         10            11        12            14        17  \
# Billie_Rogue  0.000000e+00  1.362999e-01  0.000000  0.000000e+00  0.000000
# Billie_Rogue  0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.161895
# Billie_Rogue  0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.000000
# Billie_Rogue  0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.000000
# K_Ray         1.710540e-01  0.000000e+00  0.000000  0.000000e+00  0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000  7.694263e-01  0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.000000
# K_Ray         0.000000e+00  1.583736e-16  0.000000  2.070956e-25  0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.000000
# K_Ray         1.229880e-15  0.000000e+00  0.000000  0.000000e+00  0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.165702  0.000000e+00  0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000  0.000000e+00  0.000000
#
#                     23            40       420            45            80  \
# Billie_Rogue  0.000000  0.000000e+00  0.000000  2.725997e-01  0.000000e+00
# Billie_Rogue  0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# Billie_Rogue  0.779509  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# Billie_Rogue  0.000000  3.815012e-01  0.000000  0.000000e+00  0.000000e+00
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# K_Ray         0.000000  0.000000e+00  0.000000  3.167472e-16  0.000000e+00
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  9.457747e-25
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  5.954840e-02
# K_Ray         0.000000  0.000000e+00  0.000000  0.000000e+00  0.000000e+00
# K_Ray         0.000000  6.757377e-18  0.136256  0.000000e+00  7.620614e-20
#
#               ...          yard          yeah      year         years  \
# Billie_Rogue  ...  0.000000e+00  0.000000e+00  0.000000  0.000000e+00
# Billie_Rogue  ...  0.000000e+00  1.686966e-01  0.000000  0.000000e+00
# Billie_Rogue  ...  0.000000e+00  2.754297e-24  0.000000  0.000000e+00
# Billie_Rogue  ...  0.000000e+00  9.938190e-01  0.000000  3.815012e-01
# K_Ray         ...  0.000000e+00  2.022053e-01  0.000000  0.000000e+00
# K_Ray         ...  0.000000e+00  0.000000e+00  0.000000  0.000000e+00
# K_Ray         ...  0.000000e+00  5.294918e-01  0.396037  0.000000e+00
# K_Ray         ...  0.000000e+00  2.673597e-01  0.000000  0.000000e+00
# K_Ray         ...  0.000000e+00  0.000000e+00  0.000000  0.000000e+00
# K_Ray         ...  0.000000e+00  0.000000e+00  0.116436  0.000000e+00
# K_Ray         ...  0.000000e+00  0.000000e+00  0.000000  0.000000e+00
# K_Ray         ...  0.000000e+00  1.066408e-01  0.000000  0.000000e+00
# K_Ray         ...  9.457747e-25  1.383616e-15  0.000000  0.000000e+00
# K_Ray         ...  5.954840e-02  6.204994e-02  0.000000  0.000000e+00
# K_Ray         ...  0.000000e+00  0.000000e+00  0.000000  0.000000e+00
# K_Ray         ...  7.620614e-20  9.228542e-01  0.106178  6.757377e-18
#
#                    yelling           yes            yo   younger  zimmerman  \
# Billie_Rogue  1.362999e-01  0.000000e+00  8.192160e-02  0.000000   0.000000
# Billie_Rogue  0.000000e+00  0.000000e+00  1.946111e-01  0.000000   0.000000
# Billie_Rogue  0.000000e+00  0.000000e+00  0.000000e+00  0.000000   0.000000
# Billie_Rogue  0.000000e+00  0.000000e+00  0.000000e+00  0.000000   0.000000
# K_Ray         0.000000e+00  0.000000e+00  4.665347e-01  0.000000   0.000000
# K_Ray         0.000000e+00  0.000000e+00  2.802237e-09  0.000000   0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000e+00  0.000000   0.000000
# K_Ray         0.000000e+00  0.000000e+00  5.140508e-01  0.000000   0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000e+00  0.000000   0.000000
# K_Ray         0.000000e+00  0.000000e+00  4.489044e-01  0.000000   0.000000
# K_Ray         1.583736e-16  0.000000e+00  0.000000e+00  0.000000   0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000e+00  0.204683   0.000000
# K_Ray         0.000000e+00  1.891549e-24  0.000000e+00  0.000000   0.000000
# K_Ray         0.000000e+00  1.190968e-01  0.000000e+00  0.000000   0.000000
# K_Ray         0.000000e+00  0.000000e+00  0.000000e+00  0.000000   0.165702
# K_Ray         0.000000e+00  1.524123e-19  1.637602e-01  0.000000   0.000000
#
#                  zones
# Billie_Rogue  0.000000
# Billie_Rogue  0.161895
# Billie_Rogue  0.000000
# Billie_Rogue  0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
# K_Ray         0.000000
#
# [16 rows x 1266 columns]

# %% [markdown]
# ### To evoke 10 most higher valued words for each lyric

# %%
for lyric in range(components_df.shape[0]):
    word = components_df.iloc[lyric]
    print(f'For topic {lyric+1} the words with the highest value are:')
    print(word.nlargest(10))
    print('\n')
# Out:
# For topic 1 the words with the highest value are:
# let       1.750885
# ya        1.061794
# just      0.797274
# freak     0.593500
# act       0.545199
# trying    0.426077
# store     0.408900
# sumin     0.408900
# right     0.386107
# fina      0.354451
# Name: Billie_Rogue, dtype: float64
#
#
# For topic 2 the words with the highest value are:
# mind      0.504633
# kyrie     0.323791
# post      0.323791
# shot      0.323791
# like      0.278064
# time      0.271263
# girl      0.236748
# point     0.229307
# shorty    0.229307
# ain       0.208548
# Name: Billie_Rogue, dtype: float64
#
#
# For topic 3 the words with the highest value are:
# learned      0.974386
# 23           0.779509
# debate       0.779509
# empathy      0.779509
# gonna        0.779509
# oughta       0.779509
# changed      0.678854
# everybody    0.678854
# patiently    0.678854
# turned       0.678854
# Name: Billie_Rogue, dtype: float64
#
#
# For topic 4 the words with the highest value are:
# girl         1.115778
# yeah         0.993819
# gone         0.993819
# world        0.891863
# like         0.819060
# know         0.819060
# box          0.763002
# brown        0.763002
# capacitor    0.763002
# copped       0.763002
# Name: Billie_Rogue, dtype: float64
#
#
# For topic 5 the words with the highest value are:
# ignore    1.552427
# story     1.552427
# free      1.351968
# night     1.351968
# sea       1.351968
# float     1.209740
# place     1.209740
# far       1.209740
# know      1.166538
# knife     1.164320
# Name: K_Ray, dtype: float64
#
#
# For topic 6 the words with the highest value are:
# skies          4.068361
# belong         2.905972
# let            2.596843
# closer         1.358700
# fly            1.358700
# rise           1.162389
# silverlight    1.162389
# step           1.162389
# sunburn        1.162389
# born           1.012294
# Name: K_Ray, dtype: float64
#
#
# For topic 7 the words with the highest value are:
# em       2.159536
# days     1.524679
# ways     1.524679
# went     1.327803
# men      1.327803
# like     1.309304
# women    1.188116
# ain      1.090881
# bro      1.079124
# boys     1.016452
# Name: K_Ray, dtype: float64
#
#
# For topic 8 the words with the highest value are:
# bro        2.665066
# ain        1.028279
# yo         0.514051
# money      0.514051
# sleep      0.444830
# niggas     0.411241
# shit       0.411241
# gotta      0.382144
# know       0.367243
# atlanta    0.342108
# Name: K_Ray, dtype: float64
#
#
# For topic 9 the words with the highest value are:
# naked         3.847131
# bone          1.923566
# flesh         1.923566
# wish          1.750797
# born          1.005110
# 14            0.769426
# comfort       0.769426
# dense         0.769426
# disappoint    0.769426
# hugging       0.769426
# Name: K_Ray, dtype: float64
#
#
# For topic 10 the words with the highest value are:
# thang    1.344769
# mane     1.301219
# water    0.597675
# throw    0.582178
# like     0.577338
# right    0.528958
# ass      0.520500
# clap     0.520432
# make     0.500668
# gone     0.466979
# Name: K_Ray, dtype: float64
#
#
# For topic 11 the words with the highest value are:
# sow           9.216504
# lulladie      4.608252
# eyes          4.013206
# hands         2.693260
# suffering     2.304126
# barricades    1.152063
# bliss         1.152063
# breaks        1.152063
# brush         1.152063
# embrace       1.152063
# Name: K_Ray, dtype: float64
#
#
# For topic 12 the words with the highest value are:
# trust       0.957004
# head        0.957004
# tired       0.818732
# trying      0.746486
# need        0.498865
# ain         0.439442
# humans      0.409366
# sex         0.409366
# trusting    0.409366
# girl        0.399092
# Name: K_Ray, dtype: float64
#
#
# For topic 13 the words with the highest value are:
# forget        2.606508
# pursuit       2.606508
# blissfully    0.598596
# jaded         0.598596
# wandering     0.598596
# coming        0.521302
# wondering     0.521302
# arrogant      0.299298
# atlas         0.299298
# boredom       0.299298
# Name: K_Ray, dtype: float64
#
#
# For topic 14 the words with the highest value are:
# tryna       0.414873
# order       0.414873
# drive       0.357290
# looking     0.322118
# sir         0.311155
# eat         0.238194
# holding     0.238194
# sorry       0.238194
# apple       0.178645
# complete    0.178645
# Name: K_Ray, dtype: float64
#
#
# For topic 15 the words with the highest value are:
# black      0.903870
# running    0.721527
# susie      0.662808
# home       0.497106
# white      0.497106
# let        0.462569
# bust       0.432916
# just       0.403790
# homie      0.387373
# don        0.378070
# Name: K_Ray, dtype: float64
#
#
# For topic 16 the words with the highest value are:
# smoke      2.043841
# want       1.063011
# yeah       0.922854
# got        0.464917
# bro        0.385826
# gas        0.355985
# blowing    0.355968
# gone       0.354945
# good       0.354330
# words      0.318535
# Name: K_Ray, dtype: float64
